# %%
# ----------------------------------------------------------------------------------------------------------------------- #
# -------------------------------------------------------- imports ------------------------------------------------------ #
# ---------------------------------------------------- (do not change) -------------------------------------------------- #
# ----------------------------------------------------------------------------------------------------------------------- #

from flappy_bird_evolution import * # imports the library of the evolution
import matplotlib.pyplot as plt # import the displaying library

# ----------------------------------------------------------------------------------------------------------------------- #
# -------------------------------------------------- evolution variable ------------------------------------------------- #
# -------------------------------------- (set these to change the evolution process) ------------------------------------ #
# ----------------------------------------------------------------------------------------------------------------------- #

N = 300  # number of players  

shape = [5,8,4,1] # shape of neral network. firs value must be 5. last value must be 1

reproduction_precentage = 2 # precentage of players who get rproduced

learning_rate = .1 # rate in which the ai learns

games_per_generation = 3 # games per generation

# ----------------------------------------------------------------------------------------------------------------------- #
# ------------------------------------------------ running the evolution ------------------------------------------------ #
# ---------------------------------------------------- (do not change) -------------------------------------------------- #
# ----------------------------------------------------------------------------------------------------------------------- #

Game(N, shape, learning_rate, reproduction_precentage, games_per_generation)

# ----------------------------------------------------------------------------------------------------------------------- #
# -------------------------------------- the evolution process is simulating below -------------------------------------- #
# ---------------- (press the run button to start and the stop button if you want to change the variable) --------------- #
# ----------------------------------------------------------------------------------------------------------------------- #
# Out:
# <img src="data:image/png;base64,..." width="800">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-825bd4381042> in <module>
#      27 # ----------------------------------------------------------------------------------------------------------------------- #
#      28
# ---> 29 Game(N, shape, learning_rate, reproduction_precentage, games_per_generation)
#      30
#      31 # ----------------------------------------------------------------------------------------------------------------------- #
#
# ~\ai_from_scratch\flappy_bird\flappy_bird_evolution.py in __init__(self, N, shape, lr, rp, gpr)
#      89         plt.show()
#      90
# ---> 91         self.game()
#      92
#      93     def birdDrawFirst(self, x, y, image, ax=None, zoom=1):
#
# ~\ai_from_scratch\flappy_bird\flappy_bird_evolution.py in game(self)
# ...
