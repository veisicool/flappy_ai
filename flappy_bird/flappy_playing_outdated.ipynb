# %%
# ----------------------------------------------------------------------------------------------------------------------- #
# ---------------------------------------------------- notebook setup --------------------------------------------------- #
# ---------------------------------------------- (only run this cell once) ---------------------------------------------- #
# ----------------------------------------------------------------------------------------------------------------------- #

# %matplotlib notebook 
# enables to animate the evolution process
# %matplotlib notebook 
# fixes a few bugs with display
# %matplotlib inline

# %%
# ----------------------------------------------------------------------------------------------------------------------- #
# -------------------------------------------------------- imports ------------------------------------------------------ #
# ---------------------------------------------------- (do not change) -------------------------------------------------- #
# ----------------------------------------------------------------------------------------------------------------------- #

from flappy_bird_evolution import * # imports the library of the evolution
import matplotlib.pyplot as plt # import the displaying library

# ----------------------------------------------------------------------------------------------------------------------- #
# -------------------------------------------------- evolution variable ------------------------------------------------- #
# -------------------------------------- (set these to change the evolution process) ------------------------------------ #
# ----------------------------------------------------------------------------------------------------------------------- #

N = 300  # number of players  

shape = [5,4,3,2,1] # shape of neral network. firs value must be 5. last value must be 1

reproduction_precentage = 20 # precentage of players who get rproduced

learning_rate = 0.05 # rate in which the ai learns

mutatuion_chance = 0.7 # chance that reproduction will result in mutation

games_per_generation = 5 # games per generation

# ----------------------------------------------------------------------------------------------------------------------- #
# ------------------------------------------------ running the evolution ------------------------------------------------ #
# ---------------------------------------------------- (do not change) -------------------------------------------------- #
# ----------------------------------------------------------------------------------------------------------------------- #

Game(N, shape, learning_rate, reproduction_precentage, mutatuion_chance, games_per_generation)

# ----------------------------------------------------------------------------------------------------------------------- #
# -------------------------------------- the evolution process is simulating below -------------------------------------- #
# ---------------- (press the run button to start and the stop button if you want to change the variable) --------------- #
# ----------------------------------------------------------------------------------------------------------------------- #
# Out:
# <img src="data:image/png;base64,..." width="800">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-4456333dad7d> in <module>
#      29 # ----------------------------------------------------------------------------------------------------------------------- #
#      30
# ---> 31 Game(N, shape, learning_rate, reproduction_precentage, mutatuion_chance, games_per_generation)
#      32
#      33 # ----------------------------------------------------------------------------------------------------------------------- #
#
# ~\ai_from_scratch\flappy_bird\flappy_bird_evolution.py in __init__(self, N, shape, rate, mute_precent, mc, n_games)
#      90         plt.show()
#      91
# ---> 92         self.game(N, shape, rate, mute_precent, mc, n_games)
#      93
#      94
#
# ...
